# %%
pip install responses
# Out:
# Requirement already satisfied: responses in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (0.23.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests<3.0,>=2.30.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from responses) (2.31.0)
# Requirement already satisfied: urllib3<3.0,>=1.25.10 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from responses) (1.26.16)
# Requirement already satisfied: pyyaml in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from responses) (6.0.1)
# Requirement already satisfied: types-PyYAML in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from responses) (6.0.12.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.30.0->responses) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.30.0->responses) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0,>=2.30.0->responses) (2023.7.22)

# %%
import requests as re

response = re.get('https://news.google.com/topics/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE/sections/CAQiUENCSVNOam9JYkc5allXeGZkakpDRUd4dlkyRnNYM1l5WDNObFkzUnBiMjV5Q3hJSkwyMHZNRGsyTTJvMWVnc0tDUzl0THpBNU5qTnFOU2dBKjEIACotCAoiJ0NCSVNGem9JYkc5allXeGZkako2Q3dvSkwyMHZNRGsyTTJvMUtBQVABUAE?hl=en-US&gl=US&ceid=US%3Aen')
html = response.text

print(html)
# Out:
# <!doctype html><html lang="en-US" dir="ltr"><head><base href="https://news.google.com/"><meta name="referrer" content="origin"><link rel="canonical" href="https://news.google.com/topics/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE/sections/CAQiUENCSVNOam9JYkc5allXeGZkakpDRUd4dlkyRnNYM1l5WDNObFkzUnBiMjV5Q3hJSkwyMHZNRGsyTTJvMWVnc0tDUzl0THpBNU5qTnFOU2dBKjEIACotCAoiJ0NCSVNGem9JYkc5allXeGZkako2Q3dvSkwyMHZNRGsyTTJvMUtBQVABUAE"><meta name="viewport" content="width=device-width,initial-scale=1,minimal-ui"><meta name="google-site-verification" content="AcBy5YFny2HQgVUCR18tO5YUTf6MpVlcJqGTd-a9-SI"><meta name="mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="application-name" content="News"><meta name="apple-mobile-web-app-title" content="News"><meta name="apple-mobile-web-app-status-bar-style" content="black"><meta name="theme-color" content="white"><meta name="msapplication-tap-highlight" content="no"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w16" sizes="16x16"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w24" sizes="24x24"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w32" sizes="32x32"><link rel="shortcut icon" href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w48" sizes="48x48"><link rel="preconnect" href="//www.gstatic.com"><link rel="preconnect" href="//fonts.gstatic.com"><link rel="preconnect" href="//lh3.googleusercontent.com"><link rel="preconnect" href="//lh4.googleusercontent.com"><link rel="preconnect" href="//lh5.googleusercontent.com"><link rel="preconnect" href="//lh6.googleusercontent.com"><link rel="preconnect" href="//ssl.gstatic.com"><link rel="preconnect" href="//maps.googleapis.com"><link rel="preconnect" href="https://www.google-analytics.com/analytics.js"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans+Text:400,500,700,400i,500i,700i"><link rel="manifest" crossorigin="use-credentials" href="_/DotsSplashUi/manifest.json"><link rel="home" href="/?lfhs=2"><link rel="msapplication-starturl" href="/?lfhs=2"><link rel="icon" href="//ssl.gstatic.com/gnews/logo/google_news_192.png" sizes="192x192"><link rel="apple-touch-icon-precomposed" href="//ssl.gstatic.com/gnews/logo/google_news_192.png" sizes="192x192"><link rel="msapplication-square192x192logo" href="//ssl.gstatic.com/gnews/logo/google_news_192.png" sizes="192x192"><link rel="icon" href="//ssl.gstatic.com/gnews/logo/google_news_512.png" sizes="512x512"><link rel="apple-touch-icon-precomposed" href="//ssl.gstatic.com/gnews/logo/google_news_512.png" sizes="512x512"><link rel="msapplication-square512x512logo" href="//ssl.gstatic.com/gnews/logo/google_news_512.png" sizes="512x512"><link rel="icon" href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" sizes="1024x1024"><link rel="apple-touch-icon-precomposed" href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" sizes="1024x1024"><link rel="msapplication-square1024x1024logo" href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" sizes="1024x1024"><link rel="icon" href="//ssl.gstatic.com/gnews/logo/google_news_120.png" sizes="120x120"><link rel="apple-touch-icon-precomposed" href="//ssl.gstatic.com/gnews/logo/google_news_120.png" sizes="120x120"><link rel="msapplication-square120x120logo" href="//ssl.gstatic.com/gnews/logo/google_news_120.png" sizes="120x120"><link rel="icon" href="//ssl.gstatic.com/gnews/logo/google_news_152.png" sizes="152x152"><link rel="apple-touch-icon-precomposed" href="//ssl.gstatic.com/gnews/logo/google_news_152.png" sizes="152x152"><link rel="msapplication-square152x152logo" href="//ssl.gstatic.com/gnews/logo/google_news_152.png" sizes="152x152"><link rel="ico ...
# a.l=function(e){function g(b){var c={};c[b]=k();a.cc_latency.push(c)}function m(b){var c=n("iml");b.setAttribute("data-iml",c);return c}a.cc_aid=e;a.iml_start=a.cc_latency_start_time;a.css_size=0;a.cc_latency=[];a.ccTick=g;a.onJsLoad=function(){g("jsl")};a.onCssLoad=function(){g("cssl")};a._isVisible=function(b,c){if(!c||"none"==c.style.display)return!1;var f=b.defaultView;if(f&&f.getComputedStyle&&(f=f.getComputedStyle(c),"0px"==f.height||"0px"==f.width||"hidden"==f.visibility))return!1;if(!c.getBoundingClientRect)return!0;
# var h=c.getBoundingClientRect();c=h.left+a.pageXOffset;f=h.top+a.pageYOffset;if(0>f+h.height||0>c+h.width||0>=h.height||0>=h.width)return!1;b=b.documentElement;return f<=(a.innerHeight||b.clientHeight)&&c<=(a.innerWidth||b.clientWidth)};a._recordImlEl=m;document.documentElement.addEventListener("load",function(b){b=b.target;var c;"IMG"!=b.tagName||b.hasAttribute("data-iid")||a._isLazyImage(b)||b.hasAttribute("data-noaft")||(c=m(b));if(a.aft_counter&&(b=a.aft_counter.indexOf(b),-1!==b&&(b=1===a.aft_counter.splice(b,
# 1).length,0===a.aft_counter.length&&b&&c)))a.onaft(c)},!0);a.prt=-1;a.wiz_tick=function(){var b=n("prt");a.prt=b}};}).call(this);
# l('AAbh7b')</script><script nonce="AfSSAULzDuHhxmDq-2Y3JA">var _F_cssRowKey = 'boq-dots.DotsSplashUi_desktop_ms.pdt9RLK4puw.L.W.O';var _F_combinedSignature = 'ALs0n2Ox4pA66k8tRgSpLUHaFDF4m-pzgw';function _DumpException(e) {throw e;}</script><style data-href="https://www.gstatic.com/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi_desktop_ms.pdt9RLK4puw.L.W.O/am=AAGAsiEYpgUcAEM/d=1/ed=1/rs=ALs0n2OQuq0U92A8T8jfYfU6eGJxcGKkWQ/m=collection,_b,_tp" nonce="aWvd6kOgwlM_C_TsirKUAA">html,body{height:100%;overflow:hidden}body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;color:rgba(0,0,0,.87);font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif;margin:0;-webkit-text-size-adjust:100%;text-size-adjust:100%}textarea{font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif}a{text-decoration:none;color:#2962ff}img{border:none}*{-webkit-tap-highlight-color:transparent}#apps-debug-tracers{display:none}html,body{overflow:visible}body{overflow-y:scroll}@-webkit-keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%,-50%) scale(0.2);-webkit-transform:translate(-50%,-50%) scale(0.2);transform:translate(-50%,-50%) scale(0.2)}to{-webkit-transform:translate(-50%,-50%) scale(2.2);-webkit-transform:translate(-50%,-50%) scale(2.2);transform:translate(-50%,-50%) scale(2.2)}}@keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%,-50%) scale(0.2);-webkit-transform:translate(-50%,-50%) scale(0.2);transform:translate(-50%,-50%) scale(0.2)}to{-webkit-transform:translate(-50%,-50%) scale(2.2);-webkit-transform:translate(-50%,-50%) scale(2.2);transform:translate(-50%,-50%) scale(2.2)}}@-webkit-keyframes quantumWizIconFocusPulse{0%{-webkit-transform:translate(-50%,-50%) scale(1.5);-webkit-transform:translate(-50%,-50%) scale(1.5);transform:translate(-50%,-50%) scale(1.5);opacity:0}to{-webkit-transform:translate(-50%,-50%) scale(2);-webkit-transform:translate(-50%,-50%) scale(2);transform:translate(-50%,-50%) scale(2);opacity:1}}@keyframes quantumWizIconFocusPulse{0%{-webkit-transform:translate(-50%,-50%) scale(1.5);-webkit-transform:translate(-50%,-50%) scale(1.5);transform:translate(-50%,-50%) scale(1.5);opacity:0}to{-webkit-transform:translate(-50%,-50%) scale(2);-webkit-transform:translate(-50%,-50%) scale(2);transform:translate(-50%,-50%) scale(2);opacity:1}}@-webkit-keyframes quantumWizRadialInkSpread{0%{-webkit-transform:scale(1.5);-webkit-transform:scale(1.5);transform:scale(1.5);opacity:0}to{-webkit-transform:scale(2.5);-webkit-transform:scale(2.5);transform:scale(2.5);opacity:1}}@keyframes quantumWizRadialInkSpread{0%{-webkit-transform:scale(1.5);-webkit-transform:scale(1.5);transform:scale(1.5);opacity:0}to{-webkit-transform:scale(2.5);-webkit-transform:scale(2.5);transform:scale(2.5);opacity:1}}@-webkit-keyframes quantumWizRadialInkFocusPulse{0%{-webkit-transform:scale(2);-webkit-transform:scale(2);transform:scale(2);opacity:0}to{-webkit-transform:scale(2.5);-webkit-transform:scale(2.5);transform:scale(2.5);opacity:1}}@keyframes quantumWizRadialInkFocusPulse{0%{-webkit-transform:scale(2);-webkit-transform:scale(2);transform:scale(2);opacity:0}to{-webkit-transform:scale(2.5);-webkit-transform:scale(2.5);transform:scale(2.5);opacity:1}}.O0WRkf{-webkit-user-select:none;-webkit-transition:background .2s .1s;transition:background .2s .1s;border:0;-webkit-border-radius:3px;border-radius:3px;cursor:pointer;display:inline-block;font-size:14px;font-weight:500;min-width:4em;outline:none;overflow:hidden;position:relative;text-align:center;text-transform:uppercase;-webkit-tap-highlight-color:transparent;z-index:0}.A9jyad{font-size:13px;line-height:16px}.zZhnYe{-webkit-transition:box-shadow .28s cubic-bezier(0.4,0,0.2,1);transition:box-shadow .28s cubic-bezier(0.4,0,0.2,1);background:#dfdfdf;-webkit-box-shadow:0px 2px 2px 0px rgba(0,0,0,.14),0px 3px 1px -2px rgba(0,0,0,.12),0px 1px 5px 0px rgba(0,0,0,.2);box-shadow:0px 2px 2px 0px rgba(0,0,0,.14),0px 3px 1px -2px rgba(0,0,0,.12),0px 1px 5px 0px rgba(0,0,0,.2)}.z ...
# /*# sourceURL=/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi_desktop_ms.pdt9RLK4puw.L.W.O/am=AAGAsiEYpgUcAEM/d=1/ed=1/rs=ALs0n2OQuq0U92A8T8jfYfU6eGJxcGKkWQ/m=collection,_b,_tp */</style><script nonce="AfSSAULzDuHhxmDq-2Y3JA">onCssLoad();</script><style nonce="aWvd6kOgwlM_C_TsirKUAA">@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}@font-face{font-family:'Material Icons Extended';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/materialiconsextended/v149/kJEjBvgX7BgnkSrUwT8UnLVc38YydejYY-oE_LvM.ttf)format('truetype');}.material-icons-extended{font-family:'Material Icons Extended';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;}@font-face{font-family:'Google Material Icons';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/googlematerialicons/v137/Gw6kwdfw6UnXLJCcmafZyFRXb3BL9rvi0QZG3g.otf)format('opentype');}.google-material-icons{font-family:'Google Material Icons';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;}@font-face{font-family:'Product Sans';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/productsans/v9/pxiDypQkot1TnFhsFMOfGShVF9eL.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/googlesans/v14/4UaGrENHsxJlGDuGo1OIlL3Owps.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/googlesans/v14/4UabrENHsxJlGDuGo1OIlLU94YtzCwM.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/googlesans/v14/4UabrENHsxJlGDuGo1OIlLV154tzCwM.ttf)format('truetype');}@font-face{font-family:'Google Sans Display';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/googlesansdisplay/v13/ea8FacM9Wef3EJPWRrHjgE4B6CnlZxHVDv79pA.ttf)format('truetype');}</style><script nonce="AfSSAULzDuHhxmDq-2Y3JA">(function(){'use strict';function aa(){var b=t,c=0;return function(){return c<b.length?{done:!1,value:b[c++]}:{done:!0}}};/*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# var w=this||self;/*
#
#  Copyright 2013 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# var x={};function ba(b,c){if(null===c)return!1;if("contains"in b&&1==c.nodeType)return b.contains(c);if("compareDocumentPosition"in b)return b==c||!!(b.compareDocumentPosition(c)&16);for(;c&&b!=c;)c=c.parentNode;return c==b};/*
#
#  Copyright 2011 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# function ca(b,c){return function(d){d||(d=window.event);return c.call(b,d)}}function y(b){b=b.target||b.srcElement;!b.getAttribute&&b.parentNode&&(b=b.parentNode);return b}var B="undefined"!=typeof navigator&&/Macintosh/.test(navigator.userAgent),da="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),ea={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1};function fa(){this._mouseEventsPrevented=!0}
# var ha={Enter:13," ":32},C={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},E={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},F={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0},ia={A:!0,AREA:!0,BUTTON:!0,DIALOG:!0,IMG:!0,
# INPUT:!0,LINK:!0,MENU:!0,OPTGROUP:!0,OPTION:!0,PROGRESS:!0,SELECT:!0,TEXTAREA:!0};function ja(b){this.g=b;this.h=[]};var G=w._jsa||{};G._cfc=void 0;G._aeh=void 0;/*
#
#  Copyright 2005 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# function L(){this.o=[];this.g=[];this.j=[];this.m={};this.h=null;this.l=[]}function M(b){return String.prototype.trim?b.trim():b.replace(/^\s+/,"").replace(/\s+$/,"")}
# function ka(b,c){return function n(a,k){k=void 0===k?!0:k;var e=c;if("click"==e&&(B&&a.metaKey||!B&&a.ctrlKey||2==a.which||null==a.which&&4==a.button||a.shiftKey))e="clickmod";else{var f=a.which||a.keyCode;!f&&a.key&&(f=ha[a.key]);da&&3==f&&(f=13);if(13!=f&&32!=f)f=!1;else{var g=y(a),h;(h="keydown"!=a.type||!!(!("getAttribute"in g)||(g.getAttribute("type")||g.tagName).toUpperCase()in F||"BUTTON"==g.tagName.toUpperCase()||g.type&&"FILE"==g.type.toUpperCase()||g.isContentEditable)||a.ctrlKey||a.shiftKey||
# a.altKey||a.metaKey||(g.getAttribute("type")||g.tagName).toUpperCase()in E&&32==f)||((h=g.tagName in ea)||(h=g.getAttributeNode("tabindex"),h=null!=h&&h.specified),h=!(h&&!g.disabled));if(h)f=!1;else{h=(g.getAttribute("role")||g.type||g.tagName).toUpperCase();var v=!(h in C)&&13==f;g="INPUT"!=g.tagName.toUpperCase()||!!g.type;f=(0==C[h]%f||v)&&g}}f&&(e="clickkey")}g=a.srcElement||a.target;f=N(e,a,g,"",null);var l,z;for(h=g;h&&h!=this;h=h.__owner||("#document-fragment"!==(null==(l=h.parentNode)?void 0:
# l.nodeName)?h.parentNode:null==(z=h.parentNode)?void 0:z.host)){var m=h;var q=void 0;v=m;var r=e,la=a;var p=v.__jsaction;if(!p){var D;p=null;"getAttribute"in v&&(p=v.getAttribute("jsaction"));if(D=p){p=x[D];if(!p){p={};for(var H=D.split(ma),na=H?H.length:0,I=0;I<na;I++){var A=H[I];if(A){var J=A.indexOf(":"),T=-1!=J;p[T?M(A.substr(0,J)):oa]=T?M(A.substr(J+1)):A}}x[D]=p}v.__jsaction=p}else p=pa,v.__jsaction=p}"maybe_click"==r&&p.click?(q=r,r="click"):"clickkey"==r?r="click":"click"!=r||p.click||(r=
# "clickonly");q=G._cfc&&p.click?G._cfc(v,la,p,r,q):{eventType:q?q:r,action:p[r]||"",event:null,ignore:!1};if(q.ignore||q.action)break}q&&(f=N(q.eventType,q.event||a,g,q.action||"",m,f.timeStamp));f&&"touchend"==f.eventType&&(f.event._preventMouseEvents=fa);if(q&&q.action){if(l="clickkey"==e)l=y(a),l=(l.type||l.tagName).toUpperCase(),(l=32==(a.which||a.keyCode)&&"CHECKBOX"!=l)||(l=y(a),z=l.tagName.toUpperCase(),g=(l.getAttribute("role")||"").toUpperCase(),l="BUTTON"===z||"BUTTON"===g?!0:!(l.tagName.toUpperCase()in
# ia)||"A"===z||"SELECT"===z||(l.getAttribute("type")||l.tagName).toUpperCase()in E||(l.getAttribute("type")||l.tagName).toUpperCase()in F?!1:!0);l&&(a.preventDefault?a.preventDefault():a.returnValue=!1);if("mouseenter"==e||"mouseleave"==e||"pointerenter"==e||"pointerleave"==e)if(l=a.relatedTarget,!("mouseover"==a.type&&"mouseenter"==e||"mouseout"==a.type&&"mouseleave"==e||"pointerover"==a.type&&"pointerenter"==e||"pointerout"==a.type&&"pointerleave"==e)||l&&(l===m||ba(m,l)))f.action="",f.actionElement=
# null;else{e={};for(var u in a)"function"!==typeof a[u]&&"srcElement"!==u&&"target"!==u&&(e[u]=a[u]);e.type="mouseover"==a.type?"mouseenter":"mouseout"==a.type?"mouseleave":"pointerover"==a.type?"pointerenter":"pointerleave";e.target=e.srcElement=m;e.bubbles=!1;f.event=e;f.targetElement=m}}else f.action="",f.actionElement=null;m=f;b.h&&!m.event.a11ysgd&&(u=N(m.eventType,m.event,m.targetElement,m.action,m.actionElement,m.timeStamp),"clickonly"==u.eventType&&(u.eventType="click"),b.h(u,!0));if(m.actionElement){if(b.h){if(!m.actionElement||
# "A"!=m.actionElement.tagName||"click"!=m.eventType&&"clickmod"!=m.eventType||(a.preventDefault?a.preventDefault():a.returnValue=!1),(a=b.h(m))&&k){n.call(this,a,!1);return}}else{if((k=w.document)&&!k.createEvent&&k.createEventObject)try{var K=k.createEventObject(a)}catch(ua){K=a}else K=a;m.event=K;b.l.push(m)}G._aeh&&G._aeh(m)}}}function N(b,c,d,a,k,n){return{eventType:b,event:c,targetElement:d,action:a,actionElement:k,timeStamp:n||Date.now()}}
# function qa(b,c){return function(d){var a=b,k=c,n=!1;"mouseenter"==a?a="mouseover":"mouseleave"==a?a="mouseout":"pointerenter"==a?a="pointerover":"pointerleave"==a&&(a="pointerout");if(d.addEventListener){if("focus"==a||"blur"==a||"error"==a||"load"==a||"toggle"==a)n=!0;d.addEventListener(a,k,n)}else d.attachEvent&&("focus"==a?a="focusin":"blur"==a&&(a="focusout"),k=ca(d,k),d.attachEvent("on"+a,k));return{eventType:a,i:k,capture:n}}}
# function O(b,c,d){if(!b.m.hasOwnProperty(c)){var a=ka(b,c);d=qa(d||c,a);b.m[c]=a;b.o.push(d);for(a=0;a<b.g.length;++a){var k=b.g[a];k.h.push(d.call(null,k.g))}"click"==c&&O(b,"keydown")}}L.prototype.i=function(b){return this.m[b]};
# function ra(b,c){var d=new ja(c);a:{for(var a=0;a<b.g.length;a++)if(P(b.g[a].g,c)){c=!0;break a}c=!1}if(c)return b.j.push(d),d;Q(b,d);b.g.push(d);c=b.j.concat(b.g);a=[];for(var k=[],n=0;n<b.g.length;++n){var e=b.g[n];if(R(e,c)){a.push(e);for(var f=0;f<e.h.length;++f){var g=e.g,h=e.h[f];g.removeEventListener?g.removeEventListener(h.eventType,h.i,h.capture):g.detachEvent&&g.detachEvent("on"+h.eventType,h.i)}e.h=[]}else k.push(e)}for(n=0;n<b.j.length;++n)e=b.j[n],R(e,c)?a.push(e):(k.push(e),Q(b,e));
# b.g=k;b.j=a;return d}function Q(b,c){var d=c.g;sa&&(d.style.cursor="pointer");for(d=0;d<b.o.length;++d)c.h.push(b.o[d].call(null,c.g))}function R(b,c){for(var d=0;d<c.length;++d)if(c[d].g!=b.g&&P(c[d].g,b.g))return!0;return!1}function P(b,c){for(;b!=c&&c.parentNode;)c=c.parentNode;return b==c}var sa="undefined"!=typeof navigator&&/iPhone|iPad|iPod/.test(navigator.userAgent),ma=/\s*;\s*/,oa="click",pa={};var t="click dblclick focus focusin blur error focusout keydown keyup keypress load mouseover mouseout mouseenter mouseleave submit toggle touchstart touchend touchmove touchcancel auxclick change compositionstart compositionupdate compositionend beforeinput input select textinput copy cut paste mousedown mouseup wheel contextmenu dragover dragenter dragleave drop dragstart dragend pointerdown pointermove pointerup pointercancel pointerenter pointerleave pointerover pointerout gotpointercapture lostpointercapture ended loadedmetadata pagehide pageshow visibilitychange beforematch".split(" ");
# if(!(t instanceof Array)){var S;var U="undefined"!=typeof Symbol&&Symbol.iterator&&t[Symbol.iterator];if(U)S=U.call(t);else if("number"==typeof t.length)S={next:aa()};else throw Error(String(t)+" is not an iterable or ArrayLike");for(var V,ta=[];!(V=S.next()).done;)ta.push(V.value)};var W=function(b){return{trigger:function(c){var d=b.i(c.type);d||(O(b,c.type),d=b.i(c.type));var a=c.target||c.srcElement;d&&d.call(a.ownerDocument.documentElement,c)},bind:function(c){b.h=c;b.l&&(0<b.l.length&&c(b.l),b.l=null)}}}(function(){var b=window,c=new L,d=ra(c,b.document.documentElement);t.forEach(function(n){return O(c,n)});var a,k;"onwebkitanimationend"in b&&(a="webkitAnimationEnd");O(c,"animationend",a);"onwebkittransitionend"in b&&(k="webkitTransitionEnd");O(c,"transitionend",k);return{s:c,
# u:d}}().s),X=["BOQ_wizbind"],Y=window||w;X[0]in Y||"undefined"==typeof Y.execScript||Y.execScript("var "+X[0]);for(var Z;X.length&&(Z=X.shift());)X.length||void 0===W?Y[Z]&&Y[Z]!==Object.prototype[Z]?Y=Y[Z]:Y=Y[Z]={}:Y[Z]=W;}).call(this);
# </script><script noCollect href="https://www.gstatic.com/_/mss/boq-dots/_/js/k=boq-dots.DotsSplashUi_desktop_ms.en_US.bhcJxdnWXQU.es5.O/am=AAGAsiEYpgUcAEM/d=1/excm=_b,_tp,collection/ed=1/dg=0/wt=2/ujg=1/rs=ALs0n2MmDax6xSmVr2QTKqwpjCtG2CD3SA/m=_b,_tp" id="base-js" nonce="AfSSAULzDuHhxmDq-2Y3JA">"use strict";this.default_DotsSplashUi_desktop_ms=this.default_DotsSplashUi_desktop_ms||{};(function(_){var window=this;
# try{
# /*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#  SPDX-License-Identifier: Apache-2.0 */
# /*
#
#  Copyright 2020 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2005 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2013 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2011 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2008 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# var baa,eaa,Ka,iaa,Ta,Va,jaa,kaa,gb,ib,qaa,saa,wb,uaa,vaa,xaa,Cb,Faa,Haa,Jaa,Iaa,Kaa,Laa,Maa,Oaa,lc,Tc,Vc,Vaa,bd,Yaa,Zaa,$aa,cba,ud,Ad,hba,jba,kba,lba,nba,oba,sba,uba,xba,Fba,Bba,Hba,le,Jba,Kba,Mba,xe,Sba,Tba,Uba,Vba,Wba,Fe,Xba,Yba,$ba,aca,bca,cca,dca,ica,aaa,jca,jf,kca,lf,lca,nf,qf,mca,tf,uf,vf,rca,sca,Af,Bf,tca,uca;_.ba=function(a){return function(){return aaa[a].apply(this,arguments)}};_.ca=function(a,b){return aaa[a]=b};_.ea=function(a){_.da.setTimeout(function(){throw a;},0)};
# _.fa=function(a){a&&"function"==typeof a.dispose&&a.dispose()};baa=function(a){for(var b=0,c=arguments.length;b<c;++b){var d=arguments[b];_.ha(d)?baa.apply(null,d):_.fa(d)}};_.ia=function(a,b){if(Error.captureStackTrace)Error.captureStackTrace(this,_.ia);else{var c=Error().stack;c&&(this.stack=c)}a&&(this.message=String(a));void 0!==b&&(this.cause=b);this.j=!0};_.ja=function(a){return a[a.length-1]};
# _.ka=function(a,b,c){for(var d="string"===typeof a?a.split(""):a,e=a.length-1;0<=e;--e)e in d&&b.call(c,d[e],e,a)};_.oa=function(a,b,c){b=_.ma(a,b,c);return 0>b?null:"string"===typeof a?a.charAt(b):a[b]};_.ma=function(a,b,c){for(var d=a.length,e="string"===typeof a?a.split(""):a,f=0;f<d;f++)if(f in e&&b.call(c,e[f],f,a))return f;return-1};_.pa=function(a,b){for(var c="string"===typeof a?a.split(""):a,d=a.length-1;0<=d;d--)if(d in c&&b.call(void 0,c[d],d,a))return d;return-1};
# _.ra=function(a,b){return 0<=(0,_.qa)(a,b)};_.sa=function(a,b){_.ra(a,b)||a.push(b)};_.ua=function(a,b){b=(0,_.qa)(a,b);var c;(c=0<=b)&&_.ta(a,b);return c};_.ta=function(a,b){return 1==Array.prototype.splice.call(a,b,1).length};_.va=function(a){return Array.prototype.concat.apply([],arguments)};_.xa=function(a){var b=a.length;if(0<b){for(var c=Array(b),d=0;d<b;d++)c[d]=a[d];return c}return[]};
# _.ya=function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(_.ha(d)){var e=a.length||0,f=d.length||0;a.length=e+f;for(var g=0;g<f;g++)a[e+g]=d[g]}else a.push(d)}};_.caa=function(a,b,c,d){Array.prototype.splice.apply(a,_.za(arguments,1))};_.za=function(a,b,c){return 2>=arguments.length?Array.prototype.slice.call(a,b):Array.prototype.slice.call(a,b,c)};
# _.Da=function(a,b){b=b||a;for(var c=0,d=0,e={};d<a.length;){var f=a[d++],g=_.Ba(f)?"o"+_.Ca(f):(typeof f).charAt(0)+f;Object.prototype.hasOwnProperty.call(e,g)||(e[g]=!0,b[c++]=f)}b.length=c};_.daa=function(a,b,c,d){for(var e=0,f=a.length,g;e<f;){var k=e+(f-e>>>1),l=void 0;c?l=b.call(void 0,a[k],k,a):l=b(d,a[k]);0<l?e=k+1:(f=k,g=!l)}return g?e:-e-1};_.Fa=function(a,b){a.sort(b||_.Ea)};
# _.Ga=function(a,b){if(!_.ha(a)||!_.ha(b)||a.length!=b.length)return!1;for(var c=a.length,d=eaa,e=0;e<c;e++)if(!d(a[e],b[e]))return!1;return!0};_.Ea=function(a,b){return a>b?1:a<b?-1:0};eaa=function(a,b){return a===b};_.faa=function(a,b){var c={};(0,_.Ha)(a,function(d,e){c[b.call(void 0,d,e,a)]=d});return c};Ka=function(a){_.Ia?a(_.Ia):Ja.push(a)};_.Na=function(){!_.Ia&&_.La&&_.Ma((0,_.La)());return _.Ia};_.Ma=function(a){_.Ia=a;Ja.forEach(function(b){b(_.Ia)});Ja=[]};_.n=function(a){_.Ia&&gaa(a)};
# _.u=function(){_.Ia&&haa(_.Ia)};iaa=function(){};_.Oa=function(){var a=_.da.navigator;return a&&(a=a.userAgent)?a:""};Ta=function(a){return Pa?Ra?Ra.brands.some(function(b){return(b=b.brand)&&_.Sa(b,a)}):!1:!1};_.Ua=function(a){return _.Sa(_.Oa(),a)};Va=function(){return Pa?!!Ra&&0<Ra.brands.length:!1};_.Wa=function(){return Va()?!1:_.Ua("Opera")};_.Xa=function(){return Va()?!1:_.Ua("Trident")||_.Ua("MSIE")};_.Ya=function(){return Va()?!1:_.Ua("Edge")};
# _.Za=function(){return Va()?Ta("Microsoft Edge"):_.Ua("Edg/")};_.$a=function(){return Va()?Ta("Opera"):_.Ua("OPR")};_.ab=function(){return _.Ua("Firefox")||_.Ua("FxiOS")};_.db=function(){return _.Ua("Safari")&&!(_.bb()||_.cb()||_.Wa()||_.Ya()||_.Za()||_.$a()||_.ab()||_.Ua("Silk")||_.Ua("Android"))};_.cb=function(){return Va()?!1:_.Ua("Coast")};_.bb=function(){return Va()?Ta("Chromium"):(_.Ua("Chrome")||_.Ua("CriOS"))&&!_.Ya()||_.Ua("Silk")};
# _.eb=function(){return _.Ua("Android")&&!(_.bb()||_.ab()||_.Wa()||_.Ua("Silk"))};jaa=function(a){var b={};a.forEach(function(c){b[c[0]]=c[1]});return function(c){return b[c.find(function(d){return d in b})]||""}};
# kaa=function(a){var b=_.Oa();if("Internet Explorer"===a){if(_.Xa())if((a=/rv: *([\d\.]*)/.exec(b))&&a[1])b=a[1];else{a="";var c=/MSIE +([\d\.]+)/.exec(b);if(c&&c[1])if(b=/Trident\/(\d.\d)/.exec(b),"7.0"==c[1])if(b&&b[1])switch(b[1]){case "4.0":a="8.0";break;case "5.0":a="9.0";break;case "6.0":a="10.0";break;case "7.0":a="11.0"}else a="7.0";else a=c[1];b=a}else b="";return b}var d=RegExp("([A-Z][\\w ]+)/([^\\s]+)\\s*(?:\\((.*?)\\))?","g");c=[];for(var e;e=d.exec(b);)c.push([e[1],e[2],e[3]||void 0]);
# b=jaa(c);switch(a){case "Opera":if(_.Wa())return b(["Version","Opera"]);if(_.$a())return b(["OPR"]);break;case "Microsoft Edge":if(_.Ya())return b(["Edge"]);if(_.Za())return b(["Edg"]);break;case "Chromium":if(_.bb())return b(["Chrome","CriOS","HeadlessChrome"])}return"Firefox"===a&&_.ab()||"Safari"===a&&_.db()||"Android Browser"===a&&_.eb()||"Silk"===a&&_.Ua("Silk")?(b=c[2])&&b[1]||"":""};
# _.fb=function(a){if(Va()&&"Silk"!==a){var b=Ra.brands.find(function(c){return c.brand===a});if(!b||!b.version)return NaN;b=b.version.split(".")}else{b=kaa(a);if(""===b)return NaN;b=b.split(".")}return 0===b.length?NaN:Number(b[0])};gb=function(){return Pa?!!Ra&&!!Ra.platform:!1};_.hb=function(){return gb()?"Android"===Ra.platform:_.Ua("Android")};ib=function(){return _.Ua("iPhone")&&!_.Ua("iPod")&&!_.Ua("iPad")};_.jb=function(){return ib()||_.Ua("iPad")||_.Ua("iPod")};
# _.lb=function(){return gb()?"macOS"===Ra.platform:_.Ua("Macintosh")};_.laa=function(){return gb()?"Windows"===Ra.platform:_.Ua("Windows")};_.maa=function(){return gb()?"Chrome OS"===Ra.platform:_.Ua("CrOS")};_.mb=function(a,b,c){for(var d in a)b.call(c,a[d],d,a)};_.nb=function(a,b){var c={},d;for(d in a)b.call(void 0,a[d],d,a)&&(c[d]=a[d]);return c};_.ob=function(a,b,c){var d={},e;for(e in a)d[e]=b.call(c,a[e],e,a);return d};_.naa=function(a){var b=0,c;for(c in a)b++;return b};_.oaa=function(a){for(var b in a)return a[b]};
# _.pb=function(a){var b=[],c=0,d;for(d in a)b[c++]=a[d];return b};_.qb=function(a){var b=[],c=0,d;for(d in a)b[c++]=d;return b};_.rb=function(a){for(var b in a)return!1;return!0};_.sb=function(a){var b={},c;for(c in a)b[c]=a[c];return b};_.tb=function(a,b){for(var c,d,e=1;e<arguments.length;e++){d=arguments[e];for(c in d)a[c]=d[c];for(var f=0;f<paa.length;f++)c=paa[f],Object.prototype.hasOwnProperty.call(d,c)&&(a[c]=d[c])}};
# qaa=function(a){var b=arguments.length;if(1==b&&Array.isArray(arguments[0]))return qaa.apply(null,arguments[0]);for(var c={},d=0;d<b;d++)c[arguments[d]]=!0;return c};saa=function(a){if(!_.raa)return _.ub(a);for(var b="",c=0,d=a.length-10240;c<d;)b+=String.fromCharCode.apply(null,a.subarray(c,c+=10240));b+=String.fromCharCode.apply(null,c?a.subarray(c):a);return btoa(b)};_.vb=function(a){return taa&&null!=a&&a instanceof Uint8Array};wb=function(a){return Array.prototype.slice.call(a)};
# uaa=function(a){var b=(0,_.xb)(a);1!==(b&1)&&(Object.isFrozen(a)&&(a=wb(a)),(0,_.yb)(a,b|1))};vaa=function(){var a=[];(0,_.zb)(a,1);return a};_.Bb=function(a){(0,_.zb)(a,34);return a};_.waa=function(a){(0,_.zb)(a,32);return a};xaa=function(a,b){(0,_.yb)(b,(a|0)&-255)};Cb=function(a,b){(0,_.yb)(b,(a|34)&-221)};_.Db=function(a){a=a>>11&1023;return 0===a?536870912:a};_.yaa=function(a){return 0==a.length?_.Eb():new _.Fb(a,_.Gb)};_.Hb=function(a){return a.QY===zaa};
# _.Ib=function(a){return null!==a&&"object"===typeof a&&!Array.isArray(a)&&a.constructor===Object};_.Jb=function(a,b,c,d){if(null==a){if(!c)throw Error();}else if("string"===typeof a)a=a?new _.Fb(a,_.Gb):_.Eb();else if(a.constructor!==_.Fb)if(_.vb(a))a=d?_.yaa(a):a.length?new _.Fb(new Uint8Array(a),_.Gb):_.Eb();else{if(!b)throw Error();a=void 0}return a};_.Kb=function(a){if(a&2)throw Error();};_.Nb=function(a,b,c){(b=_.Lb?b[_.Lb]:void 0)?a[_.Lb]=wb(b):c&&_.Lb&&_.Lb in a&&(a[_.Lb]=void 0)};
# _.Ob=function(){var a=Error();Aaa(a,"incident");_.ea(a)};_.Pb=function(){var a=Error();Aaa(a,"warning");return a};_.Qb=function(a){if(null!=a&&"number"!==typeof a)throw Error("O`"+typeof a+"`"+a);return a};_.Rb=function(a){if(null!=a){if("boolean"!==typeof a)throw Error("P`"+Baa(a)+"`"+a);a=!!a}return a};_.Caa=function(a){if(null==a)return a;if("boolean"===typeof a||"number"===typeof a)return!!a};_.Eaa=function(a){var b=typeof a;return"number"===b?Number.isFinite(a):"string"!==b?!1:Daa.test(a)};
# _.Sb=function(a){return"number"===typeof a&&Number.isFinite(a)||!!a&&"string"===typeof a&&isFinite(a)};_.Tb=function(a){Number.isFinite(a)||_.Ob();return a};_.Vb=function(a){return a};_.Wb=function(a){if("number"!==typeof a)throw _.Pb();Number.isFinite(a)||_.Ob();return a};_.Xb=function(a){return null==a?a:_.Wb(a)};_.Yb=function(a){if(null==a)return a;if("string"===typeof a){if(!a)return;a=+a}if("number"===typeof a)return a};
# _.Zb=function(a){if(null==a)return a;if("string"===typeof a){if(!a)return;a=+a}if("number"===typeof a)return a};_.$b=function(a){if(null!=a){if(!_.Sb(a))throw _.Pb();_.Eaa(a)||_.Ob();a="string"===typeof a?a:a}return a};_.ac=function(a){if("string"!==typeof a)throw Error();return a};_.bc=function(a){if(null!=a&&"string"!==typeof a)throw Error();return a};Faa=function(a){return null==a||"string"===typeof a?a:void 0};
# _.fc=function(a,b,c,d){var e=!1;if(null!=a&&"object"===typeof a&&!(e=Array.isArray(a))&&_.Hb(a))return a;if(!e)return c?d&2?_.cc(b):new b:void 0;e=c=(0,_.xb)(a);0===e&&(e|=d&32);e|=d&2;e!==c&&(0,_.yb)(a,e);return new b(a)};_.cc=function(a){var b=a[Gaa];if(b)return b;b=new a;_.Bb(b.na);return a[Gaa]=b};_.hc=function(a,b){gc=b;a=new a(b);gc=void 0;return a};
# _.w=function(a,b,c){null==a&&(a=gc);gc=void 0;if(null==a){var d=96;c?(a=[c],d|=512):a=[];b&&(d=d&-2095105|(b&1023)<<11)}else{if(!Array.isArray(a))throw Error();d=(0,_.xb)(a);if(d&64)return _.ic&&delete a[_.ic],a;d|=64;if(c&&(d|=512,c!==a[0]))throw Error();a:{c=a;var e=c.length;if(e){var f=e-1,g=c[f];if(_.Ib(g)){d|=256;b=+!!(d&512)-1;e=f-b;1024<=e&&(Haa(c,b,g),e=1023);d=d&-2095105|(e&1023)<<11;break a}}b&&(g=+!!(d&512)-1,b=Math.max(b,e-g),1024<b&&(Haa(c,g,{}),d|=256,b=1023),d=d&-2095105|(b&1023)<<
# 11)}}(0,_.yb)(a,d);return a};Haa=function(a,b,c){for(var d=1023+b,e=a.length,f=d;f<e;f++){var g=a[f];null!=g&&g!==c&&(c[f-b]=g)}a.length=d+1;a[d]=c};Jaa=function(a,b){return Iaa(b)};Iaa=function(a){switch(typeof a){case "number":return isFinite(a)?a:String(a);case "boolean":return a?1:0;case "object":if(a&&!Array.isArray(a)){if(_.vb(a))return saa(a);if(a instanceof _.Fb){var b=a.mb;return null==b?"":"string"===typeof b?b:a.mb=saa(b)}}}return a};
# Kaa=function(a,b,c){var d=wb(a),e=d.length,f=b&256?d[e-1]:void 0;e+=f?-1:0;for(b=b&512?1:0;b<e;b++)d[b]=c(d[b]);if(f){b=d[b]={};for(var g in f)b[g]=c(f[g])}_.Nb(d,a,!1);return d};Laa=function(a,b,c,d,e,f){if(null!=a){if(Array.isArray(a))a=e&&0==a.length&&(0,_.xb)(a)&1?void 0:f&&(0,_.xb)(a)&2?a:_.kc(a,b,c,void 0!==d,e,f);else if(_.Ib(a)){var g={},k;for(k in a)g[k]=Laa(a[k],b,c,d,e,f);a=g}else a=b(a,d);return a}};
# _.kc=function(a,b,c,d,e,f){var g=d||c?(0,_.xb)(a):0;d=d?!!(g&32):void 0;for(var k=wb(a),l=0;l<k.length;l++)k[l]=Laa(k[l],b,c,d,e,f);c&&(_.Nb(k,a,!1),c(g,k));return k};Maa=function(a){_.Hb(a)?a=lc(a,_.kc(a.na,Maa,void 0,void 0,!1,!1),!0):a instanceof _.Fb?(a=a.mb||"",a="string"===typeof a?a:new Uint8Array(a)):a=_.vb(a)?new Uint8Array(a):a;return a};_.Naa=function(a){return _.Hb(a)?a.toJSON():Iaa(a)};
# _.mc=function(a,b,c){c=void 0===c?Cb:c;if(null!=a){if(taa&&a instanceof Uint8Array)return b?a:new Uint8Array(a);if(Array.isArray(a)){var d=(0,_.xb)(a);if(d&2)return a;b&&(b=0===d||!!(d&32)&&!(d&64||!(d&16)));return b?((0,_.yb)(a,d|34),d&4&&Object.freeze(a),a):_.kc(a,_.mc,d&4?Cb:c,!0,!1,!0)}_.Hb(a)&&(c=a.na,d=(0,_.nc)(c),a=d&2?a:_.hc(a.constructor,_.oc(c,d,!0)));return a}};_.oc=function(a,b,c){var d=c||b&2?Cb:xaa,e=!!(b&32);a=Kaa(a,b,function(f){return _.mc(f,e,d)});(0,_.zb)(a,32|(c?2:0));return a};
# _.pc=function(a){var b=a.na,c=(0,_.nc)(b);return c&2?_.hc(a.constructor,_.oc(b,c,!1)):a};_.qc=function(a){var b=a.na,c=(0,_.nc)(b);return c&2?a:_.hc(a.constructor,_.oc(b,c,!0))};_.rc=function(a,b,c,d,e){var f=_.Db(b);if(c>=f||e){e=b;if(b&256)f=a[a.length-1];else{if(null==d)return;f=a[f+(+!!(b&512)-1)]={};e|=256}f[c]=d;e!==b&&(0,_.yb)(a,e)}else a[c+(+!!(b&512)-1)]=d,b&256&&(a=a[a.length-1],c in a&&delete a[c])};
# _.vc=function(a,b,c,d,e){var f=b&2,g=_.sc(a,b,c,e);Array.isArray(g)||(g=tc);var k=!(d&2),l=!(d&1);d=!!(b&32);var m=(0,_.xb)(g);0!==m||!d||f||k?m&1||(m|=1,(0,_.yb)(g,m)):(m|=33,(0,_.yb)(g,m));f?(m&2||_.Bb(g),l&&Object.freeze(g)):(f=m&2,l&&f?(g=wb(g),f=1,d&&!k&&(f|=32),(0,_.yb)(g,f),_.rc(a,b,c,g,e)):k&&m&32&&!f&&uc(g,32));return g};
# _.wc=function(a,b,c){a=a.na;var d=(0,_.nc)(a),e=d&2,f=_.vc(a,d,b,1),g=(0,_.xb)(f);if(!(g&4)){Object.isFrozen(f)&&(f=wb(f),(0,_.yb)(f,g=g&-3|32),_.rc(a,d,b,f));for(var k=0,l=0;k<f.length;k++){var m=c(f[k]);null!=m&&(f[l++]=m)}l<k&&(f.length=l);g|=21;e?g|=34:g&=-33;(0,_.yb)(f,g);g&2&&Object.freeze(f)}!e&&(g&2||Object.isFrozen(f))&&(f=wb(f),(0,_.yb)(f,g&-35),_.rc(a,d,b,f));return f};
# _.xc=function(a,b,c,d){var e=a.na,f=(0,_.nc)(e);_.Kb(f);if(null==c)return _.rc(e,f,b),a;if(!((0,_.xb)(c)&4)){Object.isFrozen(c)&&(c=wb(c));for(var g=0;g<c.length;g++)c[g]=d(c[g]);(0,_.yb)(c,5)}_.rc(e,f,b,c);return a};_.yc=function(a,b,c,d){var e=a.na,f=(0,_.nc)(e);_.Kb(f);_.rc(e,f,b,("0"===d?0===Number(c):c===d)?void 0:c);return a};_.zc=function(a,b,c){for(var d=0,e=0;e<c.length;e++){var f=c[e];null!=_.sc(a,b,f)&&(0!==d&&_.rc(a,b,d),d=f)}return d};
# _.Ac=function(a,b,c,d,e,f){var g=!!(b&2),k=_.vc(a,b,d,1,e),l=k===tc;if(l&&2!==f)return k;if(l||!((0,_.xb)(k)&4)){g=!!(b&2);var m=!!((0,_.xb)(k)&2);l=k;!g&&m&&(k=wb(k));var p=m||void 0;m=b|(p?2:0);for(var q=!1,r=0,t=0;r<k.length;r++){var v=_.fc(k[r],c,!1,m);if(null!=v){var z=!!((0,_.xb)(v.na)&2);p=p||z;q=q||!z;k[t++]=v}}t<r&&(k.length=t);k=Oaa(k,!p,!q,!0);l!==k&&_.rc(a,b,d,k,e);(g&&2!==f||1===f)&&Object.freeze(k);return k}if(3===f)return k;g?2===f&&(f=(0,_.xb)(k),k=wb(k),(0,_.yb)(k,f),_.rc(a,b,d,k,
# e)):(c=Object.isFrozen(k),1===f?c||Object.freeze(k):(f=(0,_.xb)(k),g=f&-33,c||f&2?(k=wb(k),(0,_.yb)(k,g&-3),_.rc(a,b,d,k,e)):f!==g&&(0,_.yb)(k,g)));return k};Oaa=function(a,b,c,d){d=void 0===d?!1:d;var e=(0,_.xb)(a),f=e|5;b=b?f|8:f&-9;b=c?b|16:b&-17;e!=b&&(Object.isFrozen(a)&&(a=wb(a)),(0,_.yb)(a,b),!d&&b&2&&Object.freeze(a));return a};
# _.Bc=function(a,b,c,d,e,f,g){a=a.na;var k=(0,_.nc)(a);_.Kb(k);b=_.Ac(a,k,c,b,f,2);c=null!=d?d:new c;if(g&&("number"!==typeof e||0>e||e>b.length))throw Error();void 0!=e?b.splice(e,g,c):b.push(c);(0,_.xb)(c.na)&2?uc(b,8):uc(b,16)};_.Cc=function(a,b){return null!=a?a:b};
# lc=function(a,b,c){var d=a.constructor.Ua,e=_.Db((0,_.nc)(c?a.na:b)),f=!1;if(d){if(!c){b=wb(b);var g;if(b.length&&_.Ib(g=b[b.length-1]))for(f=0;f<d.length;f++)if(d[f]>=e){Object.assign(b[b.length-1]={},g);break}f=!0}e=b;c=!c;g=(0,_.nc)(a.na);a=_.Db(g);g=+!!(g&512)-1;for(var k,l,m=0;m<d.length;m++)if(l=d[m],l<a){l+=g;var p=e[l];null==p?e[l]=c?tc:vaa():c&&p!==tc&&uaa(p)}else k||(p=void 0,e.length&&_.Ib(p=e[e.length-1])?k=p:e.push(k={})),p=k[l],null==k[l]?k[l]=c?tc:vaa():c&&p!==tc&&uaa(p)}d=b.length;
# if(!d)return b;var q;if(_.Ib(k=b[d-1])){a:{var r=k;e={};c=!1;for(var t in r)a=r[t],Array.isArray(a)&&a!=a&&(c=!0),null!=a?e[t]=a:c=!0;if(c){for(var v in e){r=e;break a}r=null}}r!=k&&(q=!0);d--}for(;0<d;d--){k=b[d-1];if(null!=k)break;var z=!0}if(!q&&!z)return b;var C;f?C=b:C=Array.prototype.slice.call(b,0,d);b=C;f&&(b.length=d);r&&b.push(r);return b};_.Ec=function(a,b){return new _.Dc(a,b)};_.Gc=function(a){return function(b){return _.Fc(a,b)}};
# _.Hc=function(a,b){b=void 0===b?window:b;return(b=b.WIZ_global_data)&&a in b?b[a]:null};_.Jc=function(a){var b=void 0===b?window:b;return new _.Ic(a,_.Hc(a,b))};_.Mc=function(a){if(a instanceof _.Kc)a=_.Lc(a);else{b:if(Paa){try{var b=new URL(a)}catch(c){b="https:";break b}b=b.protocol}else c:{b=document.createElement("a");try{b.href=a}catch(c){b=void 0;break c}b=b.protocol;b=":"===b||""===b?"https:":b}a="javascript:"!==b?a:void 0}return a};_.Nc=function(a,b){b=_.Mc(b);void 0!==b&&(a.href=b)};
# _.Qc=function(a,b,c){if(b instanceof _.Oc)a.href=_.Pc(b).toString();else{if(-1===Qaa.indexOf(c))throw Error("na`"+c);b=_.Mc(b);if(void 0===b)return;a.href=b}a.rel=c};_.Raa=function(a){var b,c,d=null==(c=(b=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)?void 0:c.call(b,"script[nonce]");(b=d?d.nonce||d.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",b)};_.Sc=function(a,b){a.src=_.Pc(b);_.Raa(a)};Tc=function(a){return-1===a.toString().indexOf("`")};
# Vc=function(a){return new _.Uc(function(b){return b.substr(0,a.length+1).toLowerCase()===a+":"})};_.Xc=function(a){return new _.Wc(a[0].toLowerCase(),Saa)};_.ad=function(a){var b=_.Yc.apply(1,arguments);if(0===b.length)return _.Zc(a[0]);for(var c=a[0],d=0;d<b.length;d++)c+=encodeURIComponent(b[d])+a[d+1];return _.Zc(c)};Vaa=function(a,b,c){c&&(b=bd(dd,c,function(){return b}));b=bd(dd,a,function(){return b});Taa.set(a,String(b));(a=b.g)&&bd(Uaa,a,function(){return b});return b};
# bd=function(a,b,c){var d=a.get(b);d||(d=c(b),a.set(b,d));return d};_.fd=function(a,b,c,d,e){e=void 0===e?!1:e;b=new _.ed(a,b,c,void 0===e?!1:e);return Vaa(a,b,d)};_.x=function(a,b){return _.fd(a,a,b)};_.id=function(a){if(!_.gd.has("startup"))throw Error("pa`startup");_.Waa.has("startup")?a.apply():_.hd.startup.push(a)};_.jd=function(a,b){b.hasOwnProperty("displayName")||(b.displayName=a);b[Xaa]=a};Yaa=function(a){a=a[Xaa];return a instanceof _.ed?a:null};_.ld=function(a){kd.push(a)};
# _.nd=function(a){_.Ha(kd,function(b){_.md(b,a)})};Zaa=function(){if(od)for(var a=od.j,b=0;b<kd.length;b++){var c=kd[b];_.ra(a,c)||a.push(c)}};$aa=function(){return _.pd(kd,function(a){return a.g})};_.rd=function(a,b){var c=_.qd[a];c||(c=_.qd[a]=[]);c.push(b)};_.aba=function(){return ib()||_.Ua("iPod")?4:_.Ua("iPad")?5:_.hb()?sd()?3:2:_.td()?1:0};
# cba=function(a){var b="";var c=_.da._F_jsUrl;if("undefined"!==typeof document&&document&&document.getElementById&&(a=document.getElementById(a))){var d=a.tagName.toUpperCase();if("SCRIPT"==d||"LINK"==d)b=a.src?a.src:a.getAttribute("href")}if(c&&b){if(c!=b)throw Error("wa`"+c+"`"+b);b=c}else b=c||b;if(!bba(b))throw Error("xa");return b};ud=function(a){return bd(dba,a.toString(),function(){return new Set})};
# _.zd=function(a,b,c,d,e){a=_.fd(a,b,d?[d]:void 0,void 0,vd);e&&wd(e).add(a);_.xd.hb().register(a,new eba(a,ud(a),c?ud(c):new Set,wd(a),c?wd(c):new Set,d));return a};Ad=function(a,b){ud(b).add(a)};_.Cd=function(a,b){if(!b&&a.hasAttribute("jsshadow"))return null;for(b=0;a=_.Bd(a);){if(a&&void 0===a&&0<b){fba||(fba=!0);break}if(a.hasAttribute("jsslot"))b+=1;else if(a.hasAttribute("jsshadow")&&0<b){--b;continue}if(0>=b)return a}return null};
# _.Bd=function(a){return a?_.Dd(a)?_.Dd(a):a.parentNode&&11===a.parentNode.nodeType?a.parentNode.host:_.Ed(a):null};_.Fd=function(a,b,c,d){for(c||(a=_.Cd(a,d));a&&void 0!==a;){if(b(a))return a;a=_.Cd(a,d)}return null};_.gba=function(a){var b;_.Fd(a,function(c){return _.Dd(c)?(b=_.Dd(c),!0):!1},!0);return b||a};hba=function(a){return _.Gd(a)?"coFSxe"===a.getAttribute("jsname"):!1};_.iba=function(a){return _.Hd(a,hba)};
# jba=function(a){if(!a)return[];var b=(_.Id.has(a)?_.Id.get(a):[]).filter(_.iba);_.Id.set(a,b);return b};_.Jd=function(a){"__jsaction"in a&&delete a.__jsaction};_.Ld=function(a){return _.Ba(a)&&void 0!==a.Kb&&a.Kb instanceof _.Kd&&void 0!==a.ob&&(void 0===a.Zb||a.Zb instanceof _.y)?!0:!1};kba=function(a){var b=a.oVa;_.Ld(a)&&(b=a.metadata?!a.metadata.fatal:void 0);return b};
# lba=function(a,b){if(!a)return _.Md();var c=a.Fk;return _.Ld(a)&&(c=a.metadata?a.metadata.Fk:void 0,a.metadata&&a.metadata.NT)?_.Nd(b,{service:{xm:_.Od}}).then(function(d){d=d.service.xm;for(var e=_.Pd(a.metadata.NT),f=e.next();!f.done;f=e.next())f=f.value,_.Qd(d.get(f.ZTa))&&(c=f.Fk);return c}):_.Md(c)};
# nba=function(a,b,c){return lba(a,c).then(function(d){if(void 0==d||0>d)return b;var e=!1;b.then(function(){e=!0},function(){});d=_.Rd(d,_.Md(null));a.metadata&&(a.metadata.rJ=!1);d.then(function(){a.metadata&&(a.metadata.rJ=!e)});return _.mba([b,d])})};oba=function(a,b){return kba(a)?b.xf(function(){return _.Md(null)}):b};
# sba=function(a,b){return _.Ld(a)&&a.metadata&&a.metadata.dL?b.then(function(c){if(!c&&a.metadata&&a.metadata.rJ){c=new pba;var d=new _.Td;c.g=void 0;var e="type.googleapis.com";e=void 0===e?"type.googleapis.com/":e;"/"!==e.substr(-1)&&(e+="/");_.Ud(d,1,e+"wiz.data.clients.WizDataTimeoutError");_.Vd(d,2,c,!1);return _.qba(_.rba(new _.Wd,2),[d])}return null},function(c){return c instanceof _.Xd?c.status:null}):b};uba=function(a,b){var c=_.Nd(a,{service:{c2:_.tba}});return _.ob(b,function(d){return c.then(function(e){return e.service.c2.j(d)})})};
# _.Yd=function(){};_.Zd=function(a,b){_.vba(null,a,void 0===b?"unknown":b)};xba=function(){var a={};a.location=document.location.toString();if(wba())try{a["top.location"]=top.location.toString()}catch(c){a["top.location"]="[external]"}else a["top.location"]="[external]";for(var b in $d)try{a[b]=$d[b].call()}catch(c){a[b]="[error] "+c.message}return a};
# Fba=function(a,b){ae.init();a&&(a=new be(a,void 0,!0),a=new yba(a),_.ce.g=a,b&&(a.g=b),zba(a));var c=function(e){return _.Zd(e,"severe")},d=null;b=function(e){_.da.$googDebugFname&&e&&e.message&&!e.fileName&&(e.message+=" in "+_.da.$googDebugFname);d?e&&e.message&&(e.message+=" [Possibly caused by: "+d+"]"):d=String(e);c(e)};_.de("_DumpException",b);_.de("_B_err",b);_.Ha([_.da].concat([]),_.ee(Aba,_.ee(Bba,!0,c),!0));28<=_.fb("Chromium")||14<=_.fb("Firefox")||11<=_.fb("Internet Explorer")||_.fb("Safari");
# 9>=_.fb("Internet Explorer")||(b=new fe(c),b.j=!0,b.g=!0,Cba(b),ge(b,"setTimeout"),ge(b,"setInterval"),Dba(b),Eba(b),_.ce.j=b)};Bba=function(a,b,c){_.Sa(c.message,"Error in protected function: ")||(c.error&&c.error.stack?b(c.error):a||b(c))};Hba=function(a){var b=_.he(_.Jc("Im6cmf"))+"/jserror";Fba(b,a);a=_.Gba(_.ie(_.Jc("cfb2h"),""));$d.buildLabel=a};_.je=function(a){var b=dd.get(a);return b?b:(b=new _.ed(a,a,[]),Vaa(a,b),b)};_.ke=function(a,b){a.__soy_skip_handler=b};le=function(){};
# Jba=function(a,b,c){a=a.style;if("string"===typeof c)a.cssText=c;else{a.cssText="";for(var d in c)if(Iba.call(c,d)){b=d;var e=c[d];0<=b.indexOf("-")?a.setProperty(b,e):a[b]=e}}};Kba=function(a,b,c){var d=typeof c;"object"===d||"function"===d?a[b]=c:null==c?a.removeAttribute(b):(d=0===b.lastIndexOf("xml:",0)?"http://www.w3.org/XML/1998/namespace":0===b.lastIndexOf("xlink:",0)?"http://www.w3.org/1999/xlink":null)?a.setAttributeNS(d,b,c):a.setAttribute(b,c)};
# _.Lba=function(){var a=new le;a.__default=Kba;a.style=Jba;return a};Mba=function(a,b,c,d,e){return b==c&&d==e};_.pe=function(a){for(var b=_.me,c=_.ne();c!==a;){var d=c.nextSibling;b.removeChild(c);_.oe.j.push(c);c=d}};_.ne=function(){return _.qe?_.qe.nextSibling:_.me.firstChild};
# _.Pba=function(a,b){b=void 0===b?{}:b;var c=void 0===b.matches?Mba:b.matches;return function(d,e,f){var g=_.oe,k=_.re,l=_.se,m=_.te,p=_.qe,q=_.me,r=_.ue;_.re=d.ownerDocument;_.oe=new Nba(d);_.ue=c;_.te=[];_.qe=null;var t=_.me=d.parentNode,v,z=Oba.call(d);if((v=11===z.nodeType||9===z.nodeType?z.activeElement:null)&&d.contains(v)){for(z=[];v!==t;)z.push(v),v=v.parentNode||(t?v.host:null);t=z}else t=[];_.se=t;try{return a(d,e,f)}finally{d=_.oe,_.ve&&0<d.g.length&&(0,_.ve)(d.g),_.we&&0<d.j.length&&(0,_.we)(d.j),
# _.re=k,_.oe=g,_.ue=r,_.te=m,_.qe=p,_.me=q,_.se=l}}};_.Qba=function(a){return _.Pba(function(b,c,d){_.me=_.qe=b;_.qe=null;c(d);_.pe(null);_.qe=_.me;_.me=_.me.parentNode;return b},a)};xe=function(a){a=a.__soy;a.h1();return a};Sba=function(a){for(;a&&!a.QG&&!Rba(a);)a=a.parentElement;return{element:a,wJ:a.QG}};
# Tba=function(){_.ye({soy:function(a){var b=a.V?a.V().el():a.mj();var c=b.__soy?xe(b):null;if(c)return _.Md(c);var d=Sba(b),e=d.element;e.aA||(e.aA=new Set);var f=e.aA;c=new Set;for(var g=_.Pd(f),k=g.next();!k.done;k=g.next())k=k.value,_.ze(b,k)&&c.add(k);c.size||(f.add(b),b.__soy_tagged_for_skip=!0);a=d.wJ?d.wJ.then(function(){f.clear();var l=b.__soy?xe(b):null;if(l)return l;e.__soy.render();return xe(b)}):_.Ae([a.sh(_.Be,d.element),_.Nd(a,{service:{ly:_.Ce}})]).then(function(l){var m=l[1].service.ly;
# return l[0].rV().then(function(p){d.element.getAttribute("jsrenderer");f.clear();e.__incrementalDOMData||m.kX(e,p.kf,p.args);if((!b.__soy||!xe(b))&&e.__incrementalDOMData){p="Hydration source "+(document.body.contains(e)?"in dom":"not in dom")+";";var q="El source "+(document.body.contains(b)?"in dom":"not in dom");_.ea(Error("Oa`"+p+"`"+q+"`"+(b.getAttribute("jscontroller")||b.getAttribute("jsmodel"))));return null}return xe(b)})});b.aA=c;b.QG=a;return a.then(function(l){return l})}})};Uba=function(){};
# Vba=function(a){var b=this.getAttribute(a);Element.prototype.setAttribute.apply(this,arguments);var c=this.getAttribute(a);_.De(this,Ee,{name:a,Wq:c,g0:b},!1)};Wba=function(a){var b=this.getAttribute(a);Element.prototype.removeAttribute.apply(this,arguments);_.De(this,Ee,{name:a,Wq:null,g0:b},!1)};Fe=function(){return!!(window.performance&&window.performance.mark&&window.performance.measure&&window.performance.clearMeasures&&window.performance.clearMarks)};
# Xba=function(a,b){for(var c=0;c<b.length;c++)try{var d=b[c].g(a);if(null!=d&&d.abort)return d}catch(e){_.ea(e)}};Yba=function(a,b){for(var c=0;c<b.length;c++)try{b[c].j(a)}catch(d){_.ea(d)}};_.Ie=function(a,b){a=a[_.Ge];if(!a||b.has(a))return _.He();b.add(a);return a.init(b)};_.Le=function(a){var b=new Set;return _.Ie(a,b).addCallback(function(){return new _.Je([].concat(_.Ke(b)).map(function(c){return c.done()}))}).addCallback(function(){return a})};
# $ba=function(a){this.N={};this.g=[];var b=Zba;this.W=function(c){if(c=b(c))c.Sa=!0;return c};this.o=a;this.ka={};this.j=null};aca=function(a,b){return _.ob(b,function(c,d){var e={};return _.Me(_.Nd(a,{jsdata:(e[d]=c,e)}).addCallback(function(f){return f.jsdata[d]}),function(){return null})})};
# bca=function(a,b){var c=_.Nd(a,{service:{resolver:_.Ne}});return _.ob(b,function(d){if("function"==typeof d)var e=d;else if(d instanceof _.A)e=d.Bo;else if(d instanceof _.y)var f=d;else{d.tb&&("function"==typeof d.tb?e=d.tb:e=d.tb.Bo);f=d.CTa;var g=d.zK}e=f?f.constructor:e;var k=_.Oe(e);var l=a.V?a.V().el():a.mj();g&&a.tE(k,g,!!f);return c.then(function(m){return m.service.resolver.resolve(l,e,d.gV,!!f)})})};
# ...
# f=g.src;a.s=_.Rh("IMG");_.af(a.s,["gb_9c","gb_pe"]);a.s.src=f;e.parentNode&&e.parentNode.insertBefore(a.s,e);a.T.appendChild(c)};Z.prototype.kb=function(a){!_.V(this.xd,"gb_p")&&a.target instanceof Node&&("keydown"==a.type?27==a.keyCode&&(a.preventDefault(),a.stopPropagation(),_.$e(this.xd,"gb_p"),this.D().focus()):_.Ng(this.xd,a.target)||("touchstart"==a.type&&(a.preventDefault(),a.stopPropagation()),_.$e(this.xd,"gb_p")))};
# Z.prototype.zc=function(){oj(this,this.G.i);this.i&&_.Dj(this,this.i.ub(),!1);this.dispatchEvent("ffc")};_.Dj=function(a,b,c){a.i&&(Vi(a.i)&&(c=b=!1),a=document.body,_.Y(a,"gb_8d",b),_.Y(a,"gb_7d",c))};Z.prototype.Ec=function(){_.Dj(this,!0,!0)};Z.prototype.Dc=function(){_.Dj(this,!1,!0)};Z.prototype.Fc=function(){var a=Vi(this.i),b=this.i.i;a?_.U("gb_Dd").appendChild(b):this.o.appendChild(b)};_.wj=function(a){return!!a.i&&_.V(a.B,"gb_zd")};
# Z.prototype.J=function(a){var b=!1;switch(a){case "back":this.R=!0;Xi(this.i);Wi(this.i,"back");b=!0;break;case "close":this.R=!0;Xi(this.i);Wi(this.i,"close");b=!0;break;case "default":this.R=!1;vj(this,this.G.i)||this.Zc?(this.i&&!this.i.isVisible("menu")&&(Xi(this.i),Wi(this.i,"menu")),b=!0):(this.i&&this.i.isVisible("back")&&Xi(this.i),this.i&&this.i.isVisible("menu")?(a=this.i,a.close(),_.$e(a.D(),"gb_p"),!_.V(a.W,"gb_p")&&_.bf(a.D(),"gb_Qc")):(a=_.U("gb_Lc",this.o))&&_.$e(a,"gb_p"),b=!1);break;
# case "none":this.R=!0,Xi(this.i),b=!1}null!=this.C&&_.Y(this.C,"gb_ed",b)};var vj=function(a,b){var c=_.w(_.F(a.j,5),!1),d=_.w(_.F(a.j,2),!1);return!(_.w(_.F(a.j,10),!1)||a.ma||_.w(_.F(a.j,44),!1))&&d&&("gb_Oa"==b||"gb_sd"==b&&(c||a.Y))};Z.prototype.vc=function(){return this.o.offsetHeight};var yj=function(a){var b=a.o.offsetHeight+"px";a.Eb!=b&&(a.Eb=b,a.Ib&&(a.Ib.style.height=b),a.dispatchEvent("resize"))};Z.prototype.jd=function(){this.M&&yj(this)};
# Z.prototype.yc=function(){if(!this.M){var a=_.Le("DIV");_.af(a,["gb_vd","gb_id"]);Ej(a,qj(this));a.style.backgroundColor=this.o.style.backgroundColor;this.na.push(a);var b=this.v;b.parentNode&&b.parentNode.insertBefore(a,b.nextSibling);this.M=a}return this.M};Z.prototype.de=function(){_.Mg(this.M);this.M=null;yj(this)};Z.prototype.Hb=function(a){2==a&&(a=0);for(var b=0;b<this.na.length;b++)Ej(this.na[b],a);rj(this,a)};
# var rj=function(a,b){if(a.F){if(2==b){b=_.x(_.J(a.j,24),"");var c=_.x(_.J(a.j,27),"")}else 1==b?(b=_.x(_.J(a.j,23),""),c=_.x(_.J(a.j,26),"")):(b=_.x(_.J(a.j,22),""),c=_.x(_.J(a.j,25),""));""==b&&""==c||pi(a.F,b,c)}},qj=function(a){a=a.na[0];return a.classList.contains("gb_Mc")?1:a.classList.contains("gb_Jd")?2:0},Ej=function(a,b){_.cf(a,["gb_Jd","gb_Mc"]);1==b?_.$e(a,"gb_Mc"):2==b&&_.$e(a,"gb_Jd")};Z.prototype.hb=function(a){this.o.style.backgroundColor=a};Z.prototype.uc=function(){return this.o.style.backgroundColor};
# Z.prototype.Ca=function(){var a=_.nf("dd");_.ai(a)&&_.ai(a).Ed(!1);_.si(a,null)};Z.prototype.ie=function(a){jj(this,a-8-10);uj(this)};var jj=function(a,b){null==a.A?a.N.log(Error("ha")):a.Z?a.N.log(Error("ia")):a.Gb=0>b?0:b},uj=function(a){null!=a.C&&("gb_Oa"==a.G.i?_.eh(a.C,"min-width",""):null!=a.Gb&&_.eh(a.C,"min-width",a.Gb+"px"))};Z.prototype.je=function(a){_.Y(_.U("gb_Dc",this.v),"gb_p",!a)};Z.prototype.ee=function(a){a&&(_.ii(_.U("gb_Ld"),a),_.Nd.i().j.then(function(b){return void b.Xd(a)}))};
# var Bj="click mousedown scroll touchstart wheel keydown".split(" "),lj=[{id:"gb_Oa",max:599},{id:"gb_sd",max:1023},{id:"gb_Xc"}],mj=[{id:{id:"oneProductControl",Ud:1},max:320},{id:{id:"twoProductControl",Ud:2},max:360},{id:{id:"threeProductControl",Ud:3},max:410},{id:hj}];var Fj;_.X.prototype.za=_.ef(function(a,b,c,d,e){return a.call(this,b,_.ef(oi,c),d,e)},_.X.prototype.listen);_.X.prototype.zb=_.X.prototype.Xh;var Gj=_.U("gb_Na");
# if(null==Gj)Fj=null;else{var Hj=_.H(_.Qd,_.gf,6)||new _.gf,Ij=new Z(Gj,Hj,_.Ud,_.U("gb_rd"));_.B("gbar.P",Z);Z.prototype.pa=Z.prototype.vc;Z.prototype.pb=Z.prototype.zj;Z.prototype.pc=Z.prototype.Hb;Z.prototype.pd=Z.prototype.hb;Z.prototype.pe=Z.prototype.yc;Z.prototype.pf=Z.prototype.jd;Z.prototype.pg=Z.prototype.de;Z.prototype.ph=Z.prototype.Ag;Z.prototype.pi=Z.prototype.Ca;Z.prototype.pj=Z.prototype.ie;Z.prototype.pk=Z.prototype.je;Z.prototype.pl=Z.prototype.ee;Z.prototype.pm=Z.prototype.J;Z.prototype.pn=
# Z.prototype.uc;Z.prototype.po=Z.prototype.xj;Z.prototype.pp=Z.prototype.Va;_.Nd.i().s.resolve(Ij);Fj=Ij}_.Jj=Fj;
# }catch(e){_._DumpException(e)}
# try{
# _.Kj=function(a,b){return _.M(a,36,b)};
# }catch(e){_._DumpException(e)}
# try{
# var Lj=document.querySelector(".gb_b .gb_d"),Mj=document.querySelector("#gb.gb_Uc");Lj&&!Mj&&_.ie(_.Vd,Lj,"click");
# }catch(e){_._DumpException(e)}
# try{
# _.Nd.i().s.then(function(a){if(a){var b=_.U("gb_Dc",a.v);b&&(b=new _.Qh(b,_.Ud),a.wj(b))}});
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# </script><c-wiz jsrenderer="fWqNsd" class="zQTmif SSPGKf" jsdata="deferred-i5" data-p="%.@.&quot;CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE&quot;,&quot;CAQiUENCSVNOam9JYkc5allXeGZkakpDRUd4dlkyRnNYM1l5WDNObFkzUnBiMjV5Q3hJSkwyMHZNRGsyTTJvMWVnc0tDUzl0THpBNU5qTnFOU2dBKjEIACotCAoiJ0NCSVNGem9JYkc5allXeGZkako2Q3dvSkwyMHZNRGsyTTJvMUtBQVABUAE&quot;,null,[[&quot;en-US&quot;,&quot;US&quot;,[&quot;FINANCE_TOP_INDICES&quot;,&quot;SPORTS_FULL_COVERAGE&quot;,&quot;WEB_TEST_1_0_0&quot;],null,[],1,1,&quot;US:en&quot;,null,null,null,null,null,null,null,false],&quot;en-US&quot;,&quot;US&quot;,true,[2,4,8,32],1,true,&quot;571028140&quot;,false,false,null,false],true,[11,&quot;CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE&quot;],null,1,true,null,null,null,true]" jsname="a9kxte" data-node-index="0;0" jsmodel="hc6Ubd" view c-wiz data-ogpc><div class="T4LgNb" jsname="a9kxte"><div class="VjFXz"></div><main class="IKXQhd" data-n-tid="26" jscontroller="aXyUec" jsaction="rcuQ6b:npT2md;"><div class="fuAp6" jsname="ReIlqe"></div><c-wiz jsrenderer="k4xIu" class="PIlOad" jslog="88930; 3:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLFtudWxsLCJDQUFxSEFnS0loWkRRa2xUUTJwdlNXSkhPV3BaVjNobVpHcEpiMEZCVUFFIl1d;track:vis" jsshadow jsdata="deferred-i6" data-p="%.@.[[&quot;en-US&quot;,&quot;US&quot;,[&quot;FINANCE_TOP_INDICES&quot;,&quot;SPORTS_FULL_COVERAGE&quot;,&quot;WEB_TEST_1_0_0&quot;],null,[],1,1,&quot;US:en&quot;,null,null,null,null,null,null,null,false],&quot;en-US&quot;,&quot;US&quot;,true,[2,4,8,32],1,true,&quot;571028140&quot;,false,false,null,false],&quot;CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE&quot;,&quot;CAQiUENCSVNOam9JYkc5allXeGZkakpDRUd4dlkyRnNYM1l5WDNObFkzUnBiMjV5Q3hJSkwyMHZNRGsyTTJvMWVnc0tDUzl0THpBNU5qTnFOU2dBKjEIACotCAoiJ0NCSVNGem9JYkc5allXeGZkako2Q3dvSkwyMHZNRGsyTTJvMUtBQVABUAE&quot;]" jscontroller="rywMl" jsaction="rcuQ6b:npT2md;" data-node-index="1;0" jsmodel="hc6Ubd pborDe" c-wiz data-n-irtl="false" data-n-tid="2"><div class="Q5Eebb"><div class="IbUd0d"><h1 class="BPNpve">Your local news</h1></div><div class="Of7uCb"><a href="https://support.google.com/googlenews/answer/9256668?ref_topic=9006244&amp;hl=en-US&amp;authuser=0" class="ZKh3Bf" target="_blank"><svg width="24" height="24" viewBox="0 0 24 24" focusable="false" class="i2ZU NMm5M"><path d="M11 7h2v2h-2zm0 4h2v6h-2z"/><path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.41 0-8-3.59-8-8s3.59-8 8-8 8 3.59 8 8-3.59 8-8 8z"/></svg>Why these locations?</a></div></div><div class="SrIvne" role="tablist" jsaction="JIbuQc:fAsfBd;"><div class="MJcqfc y2S5Db y9gXcd" jscontroller="uoG56b" jsname="w60JDf" jsaction="rcuQ6b:npT2md;YxXT3e:BSwXS;JIbuQc:wVTESc; keydown:uYT2Vb;" data-n-irtl="false" data-n-iopb="true" role="presentation"><button class="scuRWb G03iKb eLNT1d" jsaction="click:l5oCub" jsname="o2n5fe" aria-label="Scroll chips backward"><svg width="24" height="24" viewBox="0 0 24 24" focusable="false" class="YCTYjd NMm5M hhikbc"><path d="M14.29 18.71L7.59 12l6.7-6.71 1.42 1.42-5.3 5.29 5.3 5.29z"/></svg></button><div class="USKFKc LRst5d" jsname="iyUusd" role="presentation"><div class="WeiDCd"></div><div class="Gca37 iByBBf" jsname="o1L2mb" role="presentation"></div><div class="EVvw3b"></div></div><button class="scuRWb Didmac eLNT1d" jsaction="click:l5oCub" jsname="c4xuSb" aria-label="Scroll chips forward"><svg width="24" height="24" viewBox="0 0 24 24" focusable="false" class="YCTYjd NMm5M hhikbc"><path d="M9.71 18.71l-1.42-1.42 5.3-5.29-5.3-5.29 1.42-1.42 6.7 6.71z"/></svg></button></div><span data-is-tooltip-wrapper="true"><div class="VfPpkd-dgl2Hf-ppHlrf-sM5MNb" data-is-touch-wrapper="true"><button class="VfPpkd-LgbsSe VfPpkd-LgbsSe-OWXEXe-INsAgc VfPpkd-LgbsSe-OWXEXe-Bz112c-M1Soyc VfPpkd-LgbsSe-OWXEXe-dgl2Hf Rj2Mlf OLiIxf PDpWxe LQeN7 aqpp1c pnfRzc waNn5b  QR7dkc qfclad" jscontroller="soHxf" jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touch ...
# c.initAft=function(){f=0;e=Array.prototype.slice.call(document.getElementsByTagName("img")).filter(function(a){return!!a.getAttribute("data-iml")});[].forEach.call(document.getElementsByTagName("img"),function(a){try{_recordIsAboveFold(a)}catch(b){throw b.message=a.hasAttribute("data-iid")?b.message+"\nrecordIsAboveFold error for defer inlined image":b.message+("\nrecordIsAboveFold error for img element with <src: "+a.src+">"),b;}});if(0===d.length)c.onaft(f)};}).call(this);
# initAft()</script><script id="_ij" nonce="AfSSAULzDuHhxmDq-2Y3JA">window.IJ_values = ['\/\/www.google.com\/advanced_search?hl\x3den-US\x26fg\x3d1',[null,null,"",false,null,null,null,false],'0','www.google.com','https:\/\/news.google.com\/', null ,'boq_dotssplashserver_20231003.10_p1','news.google.com','US:en', 0.0 , 1.0 , 0.0 , null , null , null ,'','CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmxiaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmtaU2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnBkQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnFZU2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnJieWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmhjaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSm1jaWdBUAE,CAAqKAgKIiJDQkFTRXdvSkwyMHZNREZqY0hsNUVnWmxjeTAwTVRrb0FBUAE,CAAqJggKIiBDQkFTRWdvSkwyMHZNREZqY0hsNUVnVndkQzFRVkNnQVAB,CAAqJggKIiBDQkFTRWdvSkwyMHZNREZqY0hsNUVnVndkQzFDVWlnQVAB,CAAqJggKIiBDQkFTRWdvSkwyMHZNREZqY0hsNUVnVjZhQzFVVnlnQVAB,CAAqJggKIiBDQkFTRWdvSkwyMHZNREZqY0hsNUVnVjZhQzFJU3lnQVAB,CAAqKQgKIiNDQkFTRkFvSkwyMHZNREZqY0hsNUVnZDZhQzFJWVc1ektBQVAB,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnViQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSjBhQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnBaQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnlkU2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSjBjaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSjFheWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSm9hU2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnVieWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnpkaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmpjeWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSndiQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmliaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmxiQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnBkeWdBUAE,CAAqBwgKMJy5lwswj-KuAw,CAAqBwgKML6Ulwswt7yuAw,CAAqBwgKMLi6mgsw0sSyAw,CAAqBwgKMLH2lwswzJ-vAw,CAAqBwgKMMmAmAsw8qmvAw,CAAqBwgKMMPxlwsw5JqvAw,CAAqBwgKMMqAmAsw9KmvAw,CAAqBwgKMMT_lwsw7qivAw,CAAqBwgKMMX_lwsw76ivAw,CAAqBwgKMMy89Aows-naAg,CAAqBwgKMN30lwsw_J2vAw,CAAqBwgKMNDolwsw7ZGvAw,CAAqBwgKMIOemAswpbywAw,CAAqBwgKMNXelwswzeraAg,CAAqBwgKMPa5lwswluKuAw,CAAqBwgKMPb0lwswgZ6vAw,CAAqBwgKMKnsmAsw4fKwAw,CAAqBwgKMKjalwsw2oOvAw,CAAqBwgKMNC89AowuPiuAw,CAAqBwgKMPrWlwswrICvAw,CAAqBwgKMILDmAswtcmwAw,CAAqBwgKMM6wmAsw4rqwAw,CAAqBwgKMM-_mAswi7uwAw,CAAqBwgKMOy-mAsws8mwAw,CAAqBwgKMO3NmAsw_tewAw,CAAqBwgKMO6-mAswtsmwAw,CAAqBwgKMO2-mAswtMmwAw,CAAqBwgKMPe-mAswwMmwAw,CAAqBwgKMIXDmAswuMmwAw,CAAqBwgKMPO-mAswvcmwAw,CAAqBwgKMNTomAswt_awAw,CAAqBwgKMJLOmAswhNiwAw,CAAqBwgKMMPemAsw0-iwAw,CAAqBwgKMM_omAsw3_KwAw,CAAqBwgKMPa-mAswh9ywAw,CAAqBwgKMPTRmAswkdmwAw,CAAqBwgKMJbfmAswpumwAw,CAAqBwgKMMfwmAsw1_qwAw,CAAqBwgKMNK_mAswj7uwAw,CAAqBwgKMM7wmAsw-vqwAw,CAAqBwgKMOfwmAsw-_qwAw,CAAqBwgKMOC2mgsw08SyAw,CAAqBwgKMOC6mgsw-sSyAw,CAAqBwgKMO2-mAswtMmwAw,CAAqBwgKMMTJmgsw3tOyAw,CAAqBwgKMOG6mgsw-8SyAw,CAAqBwgKMN-2mgsw-cCyAw,CAAqBwgKMLm6mgsw1MSyAw','AfSSAULzDuHhxmDq-2Y3JA','aWvd6kOgwlM_C_TsirKUAA','DEFAULT','English (United States)','', 2023.0 ,'https:\/\/news.google.com\/topics\/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE\/sections\/CAQiUENCSVNOam9JYkc5allXeGZkakpDRUd4dlkyRnNYM1l5WDNObFkzUnBiMjV5Q3hJSkwyMHZNRGsyTTJvMWVnc0tDUzl0THpBNU5qTnFOU2dBKjEIACotCAoiJ0NCSVNGem9JYkc5allXeGZkako2Q3dvSkwyMHZNRGsyTTJvMUtBQVABUAE', null ,'ltr', false ,'https:\/\/accounts.google.com\/AccountChooser?continue\x3dhttps:\/\/news.google.com\/topics\/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE\/sections\/CAQiUENCSVNOam9JYkc5allXeGZkakpDRUd4dlkyRnNYM1l5WDNObFkzUnBiMjV5Q3hJSkwyMHZNRGsyTTJvMWVnc0tDUzl0THpBNU5qTnFOU2dBKjEIACotCAoiJ0NCSVNGem9JYkc5allXeGZkako2Q3dvSkwyMHZNRGsyTTJvMUtBQVABUAE?hl%3Den-US%26gl%3DUS%26ceid%3DUS:en\x26hl\x3den-US','\/\/accounts.google.com\/ServiceLogin?continue\x3dhttps:\/\/news.google.com\/topics\/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE\/sections\/CAQiUENCSVNOam9JYkc5allXeGZkakpDRUd4dlkyRnNYM1l5WDNObFkzUnBiMjV5Q3hJSkwyMHZNRGsyTTJvMWVnc0tDUzl0THpBNU5qTnFOU2dBKjEIACotCAoiJ0NCSVNGem9JYkc5allXeGZkako2Q3dvSkwyMHZNRGsyTTJvMUtBQVA ...
# try{
# if(_.Jj){var Nj;if(Nj=_.J(_.Jj.j,3))for(var Oj=_.Eh(Nj),Pj=0;Pj<Oj.length;Pj++)_.Gi(Oj[Pj],"ogpc","");_.Dj(_.Jj,!!_.Jj.i&&_.Jj.i.ub(),!1)};
# }catch(e){_._DumpException(e)}
# try{
# /*
#
#  SPDX-License-Identifier: Apache-2.0
# */
# var Rj,Sj;Rj=function(a){return new _.Qj(function(b){return b.substr(0,a.length+1).toLowerCase()===a+":"})};Sj={};_.Tj=function(a){this.i=a};_.Tj.prototype.toString=function(){return this.i+""};_.Tj.prototype.Bb=!0;_.Tj.prototype.Za=function(){return this.i.toString()};_.Vj=function(a){return _.Uj(a).toString()};_.Uj=function(a){return a instanceof _.Tj&&a.constructor===_.Tj?a.i:"type_error:TrustedResourceUrl"};_.Wj=function(a){var b=_.se();a=b?b.createScriptURL(a):a;return new _.Tj(a,Sj)};_.Xj="function"===typeof URL;_.Qj=function(a){this.Ni=a};_.Yj=[Rj("data"),Rj("http"),Rj("https"),Rj("mailto"),Rj("ftp"),new _.Qj(function(a){return/^[^:]*([/?#]|$)/.test(a)})];
# }catch(e){_._DumpException(e)}
# try{
# _.Zj=function(a){this.H=_.v(a)};_.z(_.Zj,_.Q);
# }catch(e){_._DumpException(e)}
# try{
# _.ak=function(a,b,c){a.rel=c;_.ha(c.toLowerCase(),"stylesheet")?(a.href=_.Vj(b),(b=_.He(a.ownerDocument&&a.ownerDocument.defaultView))&&a.setAttribute("nonce",b)):a.href=b instanceof _.Tj?_.Vj(b):b instanceof _.jd?_.kd(b):_.kd(_.mf(b))};
# }catch(e){_._DumpException(e)}
# try{
# _.bk=function(a){var b,c,d=null==(c=(b=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)?void 0:c.call(b,"script[nonce]");(b=d?d.nonce||d.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",b)};_.ck=function(a,b){return(b||document).getElementsByTagName(String(a))};
# }catch(e){_._DumpException(e)}
# try{
# var ek=function(a,b,c){a<b?dk(a+1,b):_.Ud.log(Error("ka`"+a+"`"+b),{url:c})},dk=function(a,b){if(fk){var c=_.Le("SCRIPT");c.async=!0;c.type="text/javascript";c.charset="UTF-8";c.src=_.Uj(fk);_.bk(c);c.onerror=_.ef(ek,a,b,c.src);_.ck("HEAD")[0].appendChild(c)}},gk=function(a){this.H=_.v(a)};_.z(gk,_.Q);var hk=_.H(_.Qd,gk,17)||new gk,ik,fk=(ik=_.H(hk,_.Zj,1))?_.Wj(_.J(ik,4)||""):null,jk,kk=(jk=_.H(hk,_.Zj,2))?_.Wj(_.J(jk,4)||""):null,lk=function(){dk(1,2);if(kk){var a=_.Le("LINK");a.setAttribute("type","text/css");_.ak(a,kk,"stylesheet");var b=_.He();b&&a.setAttribute("nonce",b);_.ck("HEAD")[0].appendChild(a)}};(function(){var a=_.Rd();if(_.F(a,18))lk();else{var b=_.ff(a,19)||0;window.addEventListener("load",function(){window.setTimeout(lk,b)})}})();
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# </script><div ng-non-bindable=""><div class="gb_xe">Search</div><div class="gb_ze">Clear search</div><div class="gb_ye">Close search</div><div class="gb_hd">Google apps</div><div class="gb_Nc">Main menu</div></div>
